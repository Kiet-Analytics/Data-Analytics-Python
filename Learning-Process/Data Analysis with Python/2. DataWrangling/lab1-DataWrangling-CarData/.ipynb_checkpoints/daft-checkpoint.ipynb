# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('clean_df.csv', header=0)
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make num-of-doors
# 0             0          3                122  alfa-romero          two  \
# 1             1          3                122  alfa-romero          two
# 2             2          1                122  alfa-romero          two
# 3             3          2                164         audi         four
# 4             4          2                164         audi         four
# ..          ...        ...                ...          ...          ...
# 196         200         -1                 95        volvo         four
# 197         201         -1                 95        volvo         four
# 198         202         -1                 95        volvo         four
# 199         203         -1                 95        volvo         four
# 200         204         -1                 95        volvo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...
# 0    convertible          rwd           front        88.6  0.811148  ...  \
# 1    convertible          rwd           front        88.6  0.811148  ...
# 2      hatchback          rwd           front        94.5  0.822681  ...
# 3          sedan          fwd           front        99.8  0.848630  ...
# 4          sedan          4wd           front        99.4  0.848630  ...
# ..           ...          ...             ...         ...       ...  ...
# 196        sedan          rwd           front       109.1  0.907256  ...
# 197        sedan          rwd           front       109.1  0.907256  ...
# 198        sedan          rwd           front       109.1  0.907256  ...
# 199        sedan          rwd           front       109.1  0.907256  ...
# 200        sedan          rwd           front       109.1  0.907256  ...
#
#      horsepower  peak-rpm  city-L/100km highway-L/100km    price
# 0           111    5000.0          21.0        8.703704  13495.0  \
# 1           111    5000.0          21.0        8.703704  16500.0
# 2           154    5000.0          19.0        9.038462  16500.0
# 3           102    5500.0          24.0        7.833333  13950.0
# 4           115    5500.0          18.0       10.681818  17450.0
# ..          ...       ...           ...             ...      ...
# 196         114    5400.0          23.0        8.392857  16845.0
# 197         160    5300.0          19.0        9.400000  19045.0
# 198         134    5500.0          18.0       10.217391  21485.0
# 199         106    4800.0          26.0        8.703704  22470.0
# 200         114    5400.0          19.0        9.400000  22625.0
#
#      horsepower-binned fuel-type-diesel  fuel-type-gas  aspiration-of-std
# 0                  Low            False           True               True  \
# 1                  Low            False           True               True
# 2               Medium            False           True               True
# 3                  Low            False           True               True
# 4                  Low            False           True               True
# ..                 ...              ...            ...                ...
# 196                Low            False           True               True
# 197             Medium            False           True              False
# 198             Medium            False           True               True
# 199                Low             True          False              False
# 200                Low            False           True              False
#
#      aspiration-of-turbo
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 196                False
# 197                 True
# 198                False
# 199                 True
# 200                 True
#
# [201 rows x 30 columns]

# %%
sns.regplot(x='horsepower', y='price', data=test_df)
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
# sns.boxplot(x='num-of-doors', y='price', data=df)

# %%
sns.regplot(x='horsepower', y='price', data=test_df)
plt.ylim(0,)
# Out:
# (0.0, 47541.0394890901)

# %%
plt.hist(df['body-style'])

# %%
df

# %%
df
